# %% [markdown]
# # 중간고사 문제 풀이

# %% [markdown]
# # 1. 아래 조건을 만족하는 함수 프로그램을 작성하세요.
# A. 두 개의 매개변수를 입력 받는 함수 (분자, 분모)
#
# B. 매개변수를 이용하여 나누기 수행
#
# C. 분모 값이 0일 때 0을 반환하여 ZeroDivisionError 오류 방지

# %%
def dev(a, b):
    if b == 0:
        return 0
    else:
        return a/b

# %%
print(dev(1,0))
# Out:
# 0

# %% [markdown]
# # 2.	다음 아래 코드를 리스트 컴프리헨션(List comprehension)을 이용하여 수정하세요.
# a = [1, 2, 3, 4]
# result = []
# for num in a:
#     if num % 2 == 0:
#         result.append(num * 3)
# print(result)

# %%
a = [1, 2, 3, 4]
result = [num * 3 for num in a if num % 2 == 0 ]
print(result)
# Out:
# [6, 12]

# %% [markdown]
# # 3.	이중 For문와 range함수를 이용하여 구구단 2단부터 9단까지 계산하는 프로그램을  작성하세요.

# %%
for i in range(2,10):
    for j in range(1, 10):
        result = i * j
        print(" %d X %d = %d" %(i, j, result))
        #print(f'{i} X {j} = {result}')
# Out:
#  2 X 1 = 2
#  2 X 2 = 4
#  2 X 3 = 6
#  2 X 4 = 8
#  2 X 5 = 10
#  2 X 6 = 12
#  2 X 7 = 14
#  2 X 8 = 16
#  2 X 9 = 18
#  3 X 1 = 3
#  3 X 2 = 6
#  3 X 3 = 9
#  3 X 4 = 12
#  3 X 5 = 15
#  3 X 6 = 18
#  3 X 7 = 21
#  3 X 8 = 24
#  3 X 9 = 27
#  4 X 1 = 4
#  4 X 2 = 8
#  4 X 3 = 12
#  4 X 4 = 16
#  4 X 5 = 20
#  4 X 6 = 24
#  4 X 7 = 28
#  4 X 8 = 32
#  4 X 9 = 36
#  5 X 1 = 5
#  5 X 2 = 10
#  5 X 3 = 15
#  5 X 4 = 20
#  5 X 5 = 25
#  5 X 6 = 30
#  5 X 7 = 35
#  5 X 8 = 40
#  5 X 9 = 45
#  6 X 1 = 6
#  6 X 2 = 12
#  6 X 3 = 18
#  6 X 4 = 24
#  6 X 5 = 30
#  6 X 6 = 36
#  6 X 7 = 42
#  6 X 8 = 48
#  6 X 9 = 54
#  7 X 1 = 7
#  7 X 2 = 14
#  7 X 3 = 21
#  7 X 4 = 28
#  7 X 5 = 35
#  7 X 6 = 42
#  7 X 7 = 49
#  7 X 8 = 56
#  7 X 9 = 63
#  8 X 1 = 8
#  8 X 2 = 16
#  8 X 3 = 24
#  8 X 4 = 32
#  8 X 5 = 40
#  8 X 6 = 48
#  8 X 7 = 56
#  8 X 8 = 64
#  8 X 9 = 72
#  9 X 1 = 9
#  9 X 2 = 18
#  9 X 3 = 27
#  9 X 4 = 36
#  9 X 5 = 45
#  9 X 6 = 54
#  9 X 7 = 63
#  9 X 8 = 72
#  9 X 9 = 81

# %% [markdown]
# # 4. 다음 프로그램을 작성하시오 아래와 같이 총 10줄로 이루어진 성적 Sample.txt 파일이 홈 디렉토리에 있다.
# ### Sample.txt 파일의 숫자(점수) 값을 모두 읽어, 80점 이상인 학생들의 총합과 평균값을 구하세요. 그리고 평균값을 result.txt라는 파일에 출력하는 프로그램을 작성하세요.
# ### 입력자료: Sample.txt [70, 60, 55, 75, 94, 89, 80, 80, 85, 100]

# %%
sum= 0
count= 0
mean =0.0

f = open('sample.txt', 'r')
lines = f.readlines()
f.close()
for line in lines:
    point = int(line)
    if point >= 80:
        count += 1
        sum += point 

mean = sum / count 

fw=open('result.txt', 'w')
#f.write(str(mean))
fw.write("Mean: " + str(mean) + "   ")
fw.write("Sum: " + str(sum))
fw.close()

#with open("result.txt", "w") as fw:
#    sum, mean
    #fw.write(str(mean))

# %% [markdown]
# # 5.	아래 조건을 만족하는 클래스 프로그램을 작성하세요.
# a.	클래스 이름을 Calculator로 명명
#
# b.	생성자(constructor)를 이용하여 초깃값 설정
#
# c.	생성자에는 리스트 숫자 값을 입력
#
# d.	입력된 리스트에 대해서 합(sum)과 평균(avg)을 계산하는 매서드 포함
#
# f.	계산 합(sum)과 평균(avg)을 return

# %%
class Calculator:
    def __init__(self, numberlist):
        self.numberlist = numberlist

    def sum(self):
        hab = 0
        for num in self.numberlist:
            hab += num
        self.hab = hab
        return hab
        
    def avg(self): 
        mean= 0
        #mean = self.sum()/len(self.numberlist)
        mean = self.hab/len(self.numberlist)
        return mean

# %%
cal2 =Calculator([6,7,8,9])
print(cal2.sum())
print(cal2.avg())
# Out:
# 30
# 7.5

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
#!apt-get -qq install libgeos-dev
# !pip install netCDF4
# !pip install --upgrade -q pyproj
# !pip install basemap
#!apt-get install libgeos-3.5.0
#!apt-get install libgeos-dev
#!pip install https://github.com/matplotlib/basemap/archive/master.zip
# Out:
# Collecting netCDF4
#   Obtaining dependency information for netCDF4 from https://files.pythonhosted.org/packages/b6/66/6fcd815bf53b3e1653a02356e84ed23d191baaa844c5caad31d20a31cce8/netCDF4-1.6.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading netCDF4-1.6.5-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Collecting cftime (from netCDF4)
#   Obtaining dependency information for cftime from https://files.pythonhosted.org/packages/a8/d2/75554106ea5bd1d44c73d354155395846d3833a5effe3a8660adde385288/cftime-1.6.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading cftime-1.6.3-cp311-cp311-win_amd64.whl.metadata (8.8 kB)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from netCDF4) (2023.7.22)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from netCDF4) (1.25.1)
# Downloading netCDF4-1.6.5-cp311-cp311-win_amd64.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.6 MB 2.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.3/6.6 MB 5.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/6.6 MB 7.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.3/6.6 MB 8.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.8/6.6 MB 8.8 MB/s eta 0:00:01
#    -------------- ------------------------- 2.4/6.6 MB 9.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.9/6.6 MB 9.7 MB/s eta 0:00:01
#    -------------------- ------------------- 3.4/6.6 MB 9.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.9/6.6 MB 10.1 MB/s eta 0:00:01
#    -------------------------- ------------- 4.5/6.6 MB 10.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.0/6.6 MB 10.3 MB/s eta 0:00:01
#    --------------------------------- ------ 5.5/6.6 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------ --- 6.1/6.6 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------  6.6/6.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 10.1 MB/s eta 0:00:00
# Downloading cftime-1.6.3-cp311-cp311-win_amd64.whl (188 kB)
#    ---------------------------------------- 0.0/188.2 kB ? eta -:--:--
#    ---------------------------------------- 188.2/188.2 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.3 netCDF4-1.6.5
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\USER\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\USER\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting basemap
#   Obtaining dependency information for basemap from https://files.pythonhosted.org/packages/c9/fb/0aa18cea5d108ebd35e51348ff4269b6cef10660c537e29a7ae596c5fb0b/basemap-1.3.8-cp311-cp311-win_amd64.whl.metadata
#   Downloading basemap-1.3.8-cp311-cp311-win_amd64.whl.metadata (7.7 kB)
# Collecting basemap-data<1.4,>=1.3.2 (from basemap)
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ---------------------------------------- 0.0/30.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/30.5 MB 1.7 MB/s eta 0:00:19
#       --------------------------------------- 0.6/30.5 MB 7.1 MB/s eta 0:00:05
#      - -------------------------------------- 1.1/30.5 MB 8.8 MB/s eta 0:00:04
#      -- ------------------------------------- 1.6/30.5 MB 9.5 MB/s eta 0:00:04
#      -- ------------------------------------- 2.2/30.5 MB 9.9 MB/s eta 0:00:03
#      --- ------------------------------------ 2.7/30.5 MB 10.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.3/30.5 MB 10.9 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.4/30.5 MB 10.4 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.6/30.5 MB 9.1 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.0/30.5 MB 9.2 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.2/30.5 MB 9.2 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.2/30.5 MB 8.0 MB/s eta 0:00:04
#      ------ --------------------------------- 4.8/30.5 MB 8.2 MB/s eta 0:00:04
#      ------ --------------------------------- 5.3/30.5 MB 8.5 MB/s eta 0:00:03
#      ------- -------------------------------- 5.8/30.5 MB 8.7 MB/s eta 0:00:03
#      -------- ------------------------------- 6.3/30.5 MB 8.9 MB/s eta 0:00:03
#      -------- ------------------------------- 6.3/30.5 MB 8.9 MB/s eta 0:00:03
#      -------- ------------------------------- 6.8/30.5 MB 8.4 MB/s eta 0:00:03
#      --------- ------------------------------ 7.4/30.5 MB 8.5 MB/s eta 0:00:03
#      ---------- ----------------------------- 7.9/30.5 MB 8.7 MB/s eta 0:00:03
#      ----------- ---------------------------- 8.4/30.5 MB 8.8 MB/s eta 0:00:03
#      ----------- ---------------------------- 9.0/30.5 MB 9.1 MB/s eta 0:00:03
#      ------------ --------------------------- 9.5/30.5 MB 9.2 MB/s eta 0:00:03
#      ------------- -------------------------- 10.1/30.5 MB 9.3 MB/s eta 0:00:03
#      ------------- -------------------------- 10.5/30.5 MB 9.5 MB/s eta 0:00:03
#      -------------- ------------------------- 10.9/30.5 MB 9.5 MB/s eta 0:00:03
#      --------------- ------------------------ 11.5/30.5 MB 9.5 MB/s eta 0:00:03
#      --------------- ------------------------ 12.0/30.5 MB 9.5 MB/s eta 0:00:02
#      ---------------- ----------------------- 12.6/30.5 MB 9.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 13.1/30.5 MB 9.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 13.6/30.5 MB 9.5 MB/s eta 0:00:02
#      ------------------ -------------------- 14.2/30.5 MB 10.1 MB/s eta 0:00:02
#      ------------------ -------------------- 14.7/30.5 MB 10.9 MB/s eta 0:00:02
#      ------------------- ------------------- 15.3/30.5 MB 10.9 MB/s eta 0:00:02
#      -------------------- ------------------ 15.8/30.5 MB 11.1 MB/s eta 0:00:02
#      -------------------- ------------------ 16.4/30.5 MB 10.9 MB/s eta 0:00:02
#      --------------------- ----------------- 16.9/30.5 MB 11.7 MB/s eta 0:00:02
#      ---------------------- ---------------- 17.4/30.5 MB 11.7 MB/s eta 0:00:02
#      ---------------------- ---------------- 18.0/30.5 MB 11.7 MB/s eta 0:00:02
#      ----------------------- --------------- 18.5/30.5 MB 11.7 MB/s eta 0:00:02
#      ------------------------ -------------- 19.1/30.5 MB 11.7 MB/s eta 0:00:01
#      ------------------------- ------------- 19.6/30.5 MB 11.7 MB/s eta 0:00:01
#      ------------------------- ------------- 20.2/30.5 MB 11.7 MB/s eta 0:00:01
#      -------------------------- ------------ 20.7/30.5 MB 11.7 MB/s eta 0:00:01
#      --------------------------- ----------- 21.2/30.5 MB 11.7 MB/s eta 0:00:01
#      --------------------------- ----------- 21.8/30.5 MB 11.7 MB/s eta 0:00:01
#      ---------------------------- ---------- 22.3/30.5 MB 11.7 MB/s eta 0:00:01
#      ----------------------------- --------- 22.9/30.5 MB 11.7 MB/s eta 0:00:01
#      ----------------------------- --------- 23.4/30.5 MB 11.9 MB/s eta 0:00:01
#      ------------------------------ -------- 23.9/30.5 MB 11.9 MB/s eta 0:00:01
#      ------------------------------- ------- 24.5/30.5 MB 11.9 MB/s eta 0:00:01
#      ------------------------------- ------- 25.0/30.5 MB 11.9 MB/s eta 0:00:01
#      -------------------------------- ------ 25.6/30.5 MB 11.9 MB/s eta 0:00:01
#      --------------------------------- ----- 26.1/30.5 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 26.6/30.5 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 27.2/30.5 MB 11.9 MB/s eta 0:00:01
#      ----------------------------------- --- 27.7/30.5 MB 11.7 MB/s eta 0:00:01
#      ------------------------------------ -- 28.3/30.5 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------ -- 28.8/30.5 MB 11.7 MB/s eta 0:00:01
#      ------------------------------------- - 29.4/30.5 MB 11.7 MB/s eta 0:00:01
#      --------------------------------------  29.9/30.5 MB 11.9 MB/s eta 0:00:01
#      --------------------------------------  30.4/30.5 MB 11.9 MB/s eta 0:00:01
#      --------------------------------------  30.5/30.5 MB 11.9 MB/s eta 0:00:01
#      --------------------------------------  30.5/30.5 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------------- 30.5/30.5 MB 9.5 MB/s eta 0:00:00
# Collecting pyshp<2.4,>=1.2 (from basemap)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#      ---------------------------------------- 46.5/46.5 kB ? eta 0:00:00
# Requirement already satisfied: matplotlib<3.8,>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from basemap) (3.7.2)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from basemap) (3.6.1)
# Requirement already satisfied: numpy<1.26,>=1.21 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from basemap) (1.25.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<3.8,>=1.5->basemap) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<3.8,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<3.8,>=1.5->basemap) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<3.8,>=1.5->basemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<3.8,>=1.5->basemap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<3.8,>=1.5->basemap) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<3.8,>=1.5->basemap) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<3.8,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib<3.8,>=1.5->basemap) (1.16.0)
# Downloading basemap-1.3.8-cp311-cp311-win_amd64.whl (486 kB)
#    ---------------------------------------- 0.0/486.8 kB ? eta -:--:--
#    ---------------------------------- ----- 419.8/486.8 kB 8.7 MB/s eta 0:00:01
#    --------------------------------------- 486.8/486.8 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: pyshp, basemap-data, basemap
# Successfully installed basemap-1.3.8 basemap-data-1.3.2 pyshp-2.3.1
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\USER\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## GK-2A NetCDF 파일 읽기 (적외 채널)
# ### 파이썬 서브 코드 세팅
# 1. 입력되는 관측영역과 채널에 번호에 따라 x와 y 배열수, 해상도, 그리고 지역 할당
# 2. Digital Number를 Brightness Temperature로 복사변환
# 3. 각 채널 파장 대역에 따른 Brightness Temperature(BT) 출력 (`PPT 자료 확인`)

# %%
# ==============================================================================================
# 1. GK-2A/AMI Read DIM
# ==============================================================================================
def Read_DIM(area, ch_num):
   if (area=='fd'): # fd: full disk
     if((ch_num==1) | (ch_num==2) | (ch_num==4)):
       # nm_area : 0 -> Full-disk, 1 -> CN, res=1 is 1km
       xdim=11000 # x dimension
       ydim=11000 # y dimension
       res=1 # 1km
       nm_area=0 # Full disk
     elif(ch_num==3):
       xdim=22000 # x dimension
       ydim=22000 # y dimension
       res=0.5  # 0.5 km
       nm_area=0 # Full disk
     elif((ch_num==5) | (ch_num==6)):
       xdim=5500
       ydim=5500
       res=2 # 2 km
       nm_area=0 # Full disk
   return xdim, ydim, res, nm_area

# %% [markdown]
# #### GK2A DN to Brightnee Temperature 변환 수행 함수
# - 정수형 DN 값을 물리적 값으로 변환

# %%
# ==============================================================================================
# 2. GK-2A/AMI DN to Brightness Temperature
# ==============================================================================================
# NetCDF 객체(D) 입력, 채널(ch) 입력 받는 함수
# 입력값에 대한 NetCDF 파일 읽기 수행
def DN2BT(D, ch):
   import numpy as np
   from netCDF4 import Dataset
   import netCDF4 as nc
   import math
   
   #  GK2A NetCDF에 포함호니 변수 확인
   # Variables(변수) 출력
#   print("Variables(변수):")
#   for var in D.variables:
#      print(var)

   # Attributes(속성) 출력
   print("Attributes(속성):")
   for attr in D.ncattrs():
      print(attr, ":", getattr(D, attr))

   # NetCDF에서 배열과 복사변환 계수를 입력
   row = D.getncattr('number_of_lines')
   col = D.getncattr('number_of_columns')
   gain = D.getncattr('DN_to_Radiance_Gain')
   offset = D.getncattr('DN_to_Radiance_Offset')
   
   # NetCDF에서 GK-2A DN 값 입력
   gk2a_dn=np.array(D.variables['image_pixel_values'])
   gk2a_rad = gk2a_dn*gain+offset   
   # GK-2A Bad value에 대해서 -128로 할당 (signed integer로 변환)
   gk2a_rad[gk2a_dn==32768]=-128.
# ----------------------------------------------------------------------------------------------
#  3. Setting Constants Variables
# ----------------------------------------------------------------------------------------------
   # 초기 배열 할당
   # 각각의 IR 채널 파장 중심 대역 입력
   lamda_ir = np.zeros(10) 
   lamda_ir[0]   =  3.82749133182218  # IR 3.830
   lamda_ir[1]   =  6.18196269968843  # IR 6.241
   lamda_ir[2]   =  6.93685519362696  # IR 6.952
   lamda_ir[3]   =  7.32466585491178  # IR 7.344
   lamda_ir[4]   =  8.58406387549677  # IR 8.592
   lamda_ir[5]   =  9.61575244772356  # IR 9.625
   lamda_ir[6]   = 10.35032342314430  # IR 10.403
   lamda_ir[7]   = 11.21436982235590  # IR 11.212
   lamda_ir[8]   = 12.33640374446540  # IR 12.354
   lamda_ir[9]   = 13.26980420792720  # IR 13.310

   wavenum_ir = np.zeros(10)
   wavenum_ir[0]  = 2612.677373521110
   wavenum_ir[1]  = 1617.609242531340
   wavenum_ir[2]  = 1441.575428760170
   wavenum_ir[3]  = 1365.249992024440
   wavenum_ir[4]  = 1164.949392856340
   wavenum_ir[5]  = 1039.960216776110
   wavenum_ir[6]  =  966.153383926055
   wavenum_ir[7]  =  891.713057301260
   wavenum_ir[8]  =  810.609007871230
   wavenum_ir[9]  =  753.590621482278

   planck_c    = D.getncattr('Plank_constant_h')
   light_speed = D.getncattr('light_speed')
   boltz_c     = D.getncattr('Boltzmann_constant_k')
   coef_c0     = D.getncattr('Teff_to_Tbb_c0')
   coef_c1     = D.getncattr('Teff_to_Tbb_c1')
   coef_c2     = D.getncattr('Teff_to_Tbb_c2')
  
   # DN to Brightnee temperature 계산식 （강의자료 ＰＰＴ） 참조
   c1 = 2.0 * planck_c * light_speed * light_speed
   c2 = (planck_c * light_speed) / boltz_c
   # \ => 줄 연장 연산자
   rad_tmp = c2 * ( wavenum_ir[ch] * 100. ) / \
            ( np.log( (c1 * (wavenum_ir[ch] * 100.)**3) / (gk2a_rad * 1.E-5) + 1.) )
   gk2a_bt = coef_c0 + coef_c1 * rad_tmp + coef_c2 * rad_tmp**2

   gk2a_bt[gk2a_dn==32768]=-128.

   return gk2a_bt

# %%
# ==============================================================================================
# GK-2A/AMI Read 2km (BT)
# ==============================================================================================
# ２ｋｍ 공간 해상도로 y 배열, x 배열, GK-2A 자료, 채널 번호
def READBT2KM(ydims, xdims, gk2a_ch_fn_2km, ch_nm):
  import numpy as np
  from netCDF4 import Dataset
  import netCDF4 as nc
  
  # np.zerofdfs를 이용하여 numpy 2차원 배열 실수형 자료 선언
  gk2a_ch_bt_2km = np.zeros([ydims,xdims],dtype=np.float32)

  # gk2a_ch_fn_2km 파일 크기는 출력 #############
  f'the size of gk2a_ch_fn_2km file {os.path.getsize(gk2a_ch_fn_2km)}' # 
  if os.path.getsize(gk2a_ch_fn_2km) != 0:
    # NetCDF 객체 읽기
    D = Dataset(gk2a_ch_fn_2km, mode='r')
    # GK2A Digital Number to Brightness Temperature function 사용
    gk2a_ch_bt_2km = DN2BT(D, ch_nm)
    # 16bit(2byte) 정수형 자료를 실수형으로 변환
  gk2a_ch_bt_2km = gk2a_ch_bt_2km.astype(np.float32)
  #print('[Reading Complete]', gk2a_ch_fn_2km)
  return gk2a_ch_bt_2km

# ==============================================================================================
# GK-2A/AMI Image 생성 수행
# ==============================================================================================
#           GK2A, 128.2, output_path directory, output file name
# BT2IMAGE(gk2a_ch11_bt_2km, 128.2, opath_img, out_nm_ch11)
def BT2IMAGE(data, lon_info, opath_info, output_nm):
  from mpl_toolkits.basemap import Basemap
  import matplotlib.pyplot as plt
  import pylab

  lon_0 = lon_info # 128.2
  # Basemap의 Resolution 인자는 지도의 세부 사항을 결정
  m1 = Basemap(projection='geos',lon_0=lon_0, resolution=None) # 
  
  # 0 보다 작은 값에 대해서 Mask 처리
  nbar=ma.masked_where((data < 0)  ,data)
  # geos= geostationary 투영법
  # lon_0 = 기준 경도
  # resolution = 지도해상도 (intermediate)
  # area_thresh = 지도 세부사항 임계값 (10000 : 100km X 100km 이하 호수,섬은 X)
  # rsphere=지구의 반지름을 설정. 적도 반지름(6378137.0), 극 반지름(6356752.3)
  map = Basemap(projection='geos',lon_0=lon_0,resolution='i', \
                area_thresh=10000., satellite_height=35785863.0, \
                rsphere=(6378137.0 , 6356752.3 ), \
                llcrnrx = -5499999.901174725, llcrnry = -5499999.901174725, \
                urcrnrx = 5499999.901174725, urcrnry = 5499999.901174725)

  map.drawcoastlines(linewidth=0.5) # 해안선 두께
  map.drawcountries(linewidth=0.5, color='k') # 국경선 두께와 색
  map.drawparallels(np.arange(-90.,90.,20)) # 위도선 -90~+90 20도 간격
  map.drawmeridians(np.arange(-180.,180.,20)) # 경도선
  # origin='uuper' 이미지의 LeftUpper가 (0,0)                                            
  map.imshow(nbar, interpolation='nearest', origin='upper', cmap=matplotlib.colormaps.get_cmap('jet'), vmin=200., vmax=350.)  ## min, max
  # 컬러바 추가 코드, size=5%는 컬러바 너비, pad는 지도와 colorbar 간격 (5%)
  cbar = m1.colorbar(size="5%", pad = 0.05)
  cbar.set_label('Brightness Temperature [K]')
  plt.title(output_nm, fontsize=13, y=1.01)
  plt.axis('on')    ##  'on ' have edge line / 'off' have no edge line
  plt.savefig(opath_info+output_nm+'.png', dpi=300, bbox_inches='tight')
  plt.show()        ## Show the output image before saving
  plt.close('all')

  print('[Imaging Complete] :', output_nm)


print("[Setting sub code] Complete")
# Out:
# [Setting sub code] Complete

# %% [markdown]
# 파이썬 라이브러리 세팅

# %%
from netCDF4 import Dataset
import netCDF4 as nc
import numpy as np
import glob, os
import math
from pylab import *   # matplotlib를 설치할 때 같이 설치되는 모듈 (pyplot으로 대체될 듯)

# %% [markdown]
# GK-2A 자료입출력 디렉토리 경로 설정

# %%
# input 디렉토리 (home directory)
ipath        = "./"
# GK-2A 채널 자료
ipath_l1b    = ipath+"input_data/channel/"
ipath_latlon = ipath+"input_data/latlon/"
ipath_lsmask = ipath+"input_data/lsmask/"

opath = ipath+"output_01_bin/"
if not os.path.exists(opath): os.mkdir(opath)
opath_img = opath+"img/"
if not os.path.exists(opath_img): os.mkdir(opath_img)

# %% [markdown]
# 변수 설정

# %%
#-------------------------------------------------------------------------------
# 날짜 설정 (일반적으로는 파일 이름에서 가져옴)
date = "202103290300"
yy = date[0:4]
mm = date[4:6]
dd = date[6:8]
hh = date[8:10]
mn = date[10:12]
gk2a_date = yy+mm+dd+hh+mn
print("[GK-2A/AMI Scene Information] :", gk2a_date)

#-------------------------------------------------------------------------------
# 상수 설정 (GK-2A IR 채널 읽기 용)
# 1km 채널과 red 500m을 읽을 때는 다른 상수 적용필요 => 추후 파일 명에서 자동 입력
xdims_020= 5500 ; ydims_020= 5500 ; res_020=2
# Out:
# [GK-2A/AMI Scene Information] : 202103290300

# %% [markdown]
# 천리안위성 2호 위도, 경도, 육상/해상 마스크 정보 읽기

# %%
# 위도, 경도, Landsea mask 파일 (Binary with fromfile) 읽기 
gk2a_lat_2km    = np.fromfile(ipath_latlon+'Lat_2km.bin',dtype=np.float32).reshape(5500,5500)
gk2a_lon_2km    = np.fromfile(ipath_latlon+'Lon_2km.bin',dtype=np.float32).reshape(5500,5500)
gk2a_lsmask_2km = np.fromfile(ipath_lsmask+'lsmask_2km.bin',dtype=np.int16).reshape(5500,5500)
print("[Reading complete] : GK-2A/AMI Latitude, Longitude, Land/Sea Mask")
# Out:
# [Reading complete] : GK-2A/AMI Latitude, Longitude, Land/Sea Mask

# %% [markdown]
# 천리안위성 2호 Channel 자료 읽기

# %%
#-------------------------------------------------------------------------------
# 8.7 micrometer channel
gk2a_ch11_fn = ipath_l1b+'gk2a_ami_le1b_ir087_fd020ge_'+gk2a_date+'.nc'

# GK2A 위성 IR 채널 상수를 이용한 DN to Radiance, BT 자료 산출
gk2a_ch11_bt_2km = READBT2KM(ydims_020, xdims_020, gk2a_ch11_fn, 4) # 4는 8.7채널
out_nm_ch11 = 'gk2a_ami_le1b_ir087_fd020ge_'+gk2a_date
# GK2A 위성 IR BT자료를 이용한 이미지 출력 
BT2IMAGE(gk2a_ch11_bt_2km, 128.2, opath_img, out_nm_ch11)

#-------------------------------------------------------------------------------
# 10.5 micrometer channel
gk2a_ch13_fn = ipath_l1b+'gk2a_ami_le1b_ir105_fd020ge_'+gk2a_date+'.nc'
gk2a_ch13_bt_2km = READBT2KM(ydims_020, xdims_020, gk2a_ch13_fn, 6)
out_nm_ch13 = 'gk2a_ami_le1b_ir105_fd020ge_'+gk2a_date
BT2IMAGE(gk2a_ch13_bt_2km, 128.2, opath_img, out_nm_ch13)

#-------------------------------------------------------------------------------
# 12.4 micrometer channel
gk2a_ch15_fn = ipath_l1b+'gk2a_ami_le1b_ir123_fd020ge_'+gk2a_date+'.nc'
gk2a_ch15_bt_2km = READBT2KM(ydims_020, xdims_020, gk2a_ch15_fn, 8)
out_nm_ch15 = 'gk2a_ami_le1b_ir123_fd020ge_'+gk2a_date
BT2IMAGE(gk2a_ch15_bt_2km, 128.2, opath_img, out_nm_ch15)

print('[Reading complete] GK-2A/AMI Channel Data')
# 파일 출력을 위한 파일객체(f) 반환
# Numpy 배열이 gk2a_ch11_bt_2km를 이진 파일을 출력하는 tofile Numpy 메소드를 사용
f = open(opath+"gk2a_ir087_"+gk2a_date+".bin", "w")
gk2a_ch11_bt_2km.tofile(f)  ; f.close()

f = open(opath+"gk2a_ir105_"+gk2a_date+".bin", "w")
gk2a_ch13_bt_2km.tofile(f)  ; f.close()

f = open(opath+"gk2a_ir124_"+gk2a_date+".bin", "w")
gk2a_ch15_bt_2km.tofile(f)  ; f.close()

print("All code complete")
# Out:
# Attributes(속성):
# satellite_name : GK-2A
# instrument_name : AMI
# data_processing_center : NMSC
# data_processing_mode : operation
# channel_spatial_resolution : 2.0
# channel_center_wavelength : 8.7
# scene_acquisition_time : 20210329_030033
# mission_reference_time : 20210329_030000
# file_generation_time : 20210329_031008
# file_name : gk2a_ami_le1b_ir087_fd020ge_202103290300.nc
# file_format_version : 1.0.0_20181120
# geometric_correction_sw_version : GK2_INRSM_V1.3
# star_catalog_version : 1.0.0_20170303
# landmark_catalog_version : 1.0.0_20190502
# calibration_table_version : v.3.0_20190415
# DN_to_Radiance_Gain : -0.0144806550815701
# DN_to_Radiance_Offset : 118.050903320312
# Teff_to_Tbb_c0 : -0.141418528203155
# Teff_to_Tbb_c1 : 1.00052232906885
# Teff_to_Tbb_c2 : -3.6287276076109e-07
# light_speed : 299792458.0
# Plank_constant_h : 6.62606957e-34
# Boltzmann_constant_k : 1.3806488e-23
# total_pixel_data_size : 60500000
# number_of_total_swaths : 23
# number_of_columns : 5500
# number_of_lines : 5500
# observation_mode : FD
# observation_start_time : 670258833.016741
# observation_end_time : 670259376.6659164
# time_synchro_obt : 670258833.016741
# time_synchro_utc : 670258832.9538686
# projection_type : GEOS
# sub_longitude : 2.2375121010567303
# cfac : 20425338.903339352
# lfac : -20425338.903339352
# coff : 2750.5
# loff : 2750.5
# nominal_satellite_height : 42164000.0
# earth_equatorial_radius : 6378137.0
# earth_polar_radius : 6356752.3
# earth_ellipsoid_center : [0. 0. 0.]
# image_upperleft_latitude : -100000000000000.0
# image_upperleft_longitude : -100000000000000.0
# image_lowerright_latitude : -100000000000000.0
# image_lowerright_longitude : -100000000000000.0
# image_center_latitude : 0.0
# image_center_longitude : 2.2375121010567307
# image_upperleft_x : -0.153972
# image_upperleft_y : 0.153972
# image_lowerright_x : 0.153972
# image_lowerright_y : -0.153972
# resampling_kernel_type : SINC
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_91296\2687566843.py:75: RuntimeWarning: invalid value encountered in log
#   ( np.log( (c1 * (wavenum_ir[ch] * 100.)**3) / (gk2a_rad * 1.E-5) + 1.) )
# [Imaging Complete] : gk2a_ami_le1b_ir087_fd020ge_202103290300
# Attributes(속성):
# satellite_name : GK-2A
# instrument_name : AMI
# data_processing_center : NMSC
# data_processing_mode : operation
# channel_spatial_resolution : 2.0
# channel_center_wavelength : 10.5
# scene_acquisition_time : 20210329_030033
# mission_reference_time : 20210329_030000
# file_generation_time : 20210329_031008
# file_name : gk2a_ami_le1b_ir105_fd020ge_202103290300.nc
# file_format_version : 1.0.0_20181120
# geometric_correction_sw_version : GK2_INRSM_V1.3
# star_catalog_version : 1.0.0_20170303
# landmark_catalog_version : 1.0.0_20190502
# calibration_table_version : v.3.0_20190415
# DN_to_Radiance_Gain : -0.0198196955025196
# DN_to_Radiance_Offset : 161.580139160156
# Teff_to_Tbb_c0 : -0.142866448475177
# Teff_to_Tbb_c1 : 1.00064069572049
# Teff_to_Tbb_c2 : -5.50443294960498e-07
# light_speed : 299792458.0
# Plank_constant_h : 6.62606957e-34
# Boltzmann_constant_k : 1.3806488e-23
# total_pixel_data_size : 60500000
# number_of_total_swaths : 23
# number_of_columns : 5500
# number_of_lines : 5500
# observation_mode : FD
# observation_start_time : 670258833.016741
# observation_end_time : 670259376.6659164
# time_synchro_obt : 670258833.016741
# time_synchro_utc : 670258832.9538686
# projection_type : GEOS
# sub_longitude : 2.2375121010567303
# cfac : 20425338.903339352
# lfac : -20425338.903339352
# coff : 2750.5
# loff : 2750.5
# nominal_satellite_height : 42164000.0
# earth_equatorial_radius : 6378137.0
# earth_polar_radius : 6356752.3
# earth_ellipsoid_center : [0. 0. 0.]
# image_upperleft_latitude : -100000000000000.0
# image_upperleft_longitude : -100000000000000.0
# image_lowerright_latitude : -100000000000000.0
# image_lowerright_longitude : -100000000000000.0
# image_center_latitude : 0.0
# image_center_longitude : 2.2375121010567307
# image_upperleft_x : -0.153972
# image_upperleft_y : 0.153972
# image_lowerright_x : 0.153972
# image_lowerright_y : -0.153972
# resampling_kernel_type : SINC
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_91296\2687566843.py:75: RuntimeWarning: invalid value encountered in log
#   ( np.log( (c1 * (wavenum_ir[ch] * 100.)**3) / (gk2a_rad * 1.E-5) + 1.) )
# [Imaging Complete] : gk2a_ami_le1b_ir105_fd020ge_202103290300
# Attributes(속성):
# satellite_name : GK-2A
# instrument_name : AMI
# data_processing_center : NMSC
# data_processing_mode : operation
# channel_spatial_resolution : 2.0
# channel_center_wavelength : 12.3
# scene_acquisition_time : 20210329_030033
# mission_reference_time : 20210329_030000
# file_generation_time : 20210329_031008
# file_name : gk2a_ami_le1b_ir123_fd020ge_202103290300.nc
# file_format_version : 1.0.0_20181120
# geometric_correction_sw_version : GK2_INRSM_V1.3
# star_catalog_version : 1.0.0_20170303
# landmark_catalog_version : 1.0.0_20190502
# calibration_table_version : v.3.0_20190415
# DN_to_Radiance_Gain : -0.023379972204566
# DN_to_Radiance_Offset : 190.649627685546
# Teff_to_Tbb_c0 : -0.458113885722738
# Teff_to_Tbb_c1 : 1.00245520975535
# Teff_to_Tbb_c2 : -2.53064314720476e-06
# light_speed : 299792458.0
# Plank_constant_h : 6.62606957e-34
# Boltzmann_constant_k : 1.3806488e-23
# total_pixel_data_size : 60500000
# number_of_total_swaths : 23
# number_of_columns : 5500
# number_of_lines : 5500
# observation_mode : FD
# observation_start_time : 670258833.016741
# observation_end_time : 670259376.6659164
# time_synchro_obt : 670258833.016741
# time_synchro_utc : 670258832.9538686
# projection_type : GEOS
# sub_longitude : 2.2375121010567303
# cfac : 20425338.903339352
# lfac : -20425338.903339352
# coff : 2750.5
# loff : 2750.5
# nominal_satellite_height : 42164000.0
# earth_equatorial_radius : 6378137.0
# earth_polar_radius : 6356752.3
# earth_ellipsoid_center : [0. 0. 0.]
# image_upperleft_latitude : -100000000000000.0
# image_upperleft_longitude : -100000000000000.0
# image_lowerright_latitude : -100000000000000.0
# image_lowerright_longitude : -100000000000000.0
# image_center_latitude : 0.0
# image_center_longitude : 2.2375121010567307
# image_upperleft_x : -0.153972
# image_upperleft_y : 0.153972
# image_lowerright_x : 0.153972
# image_lowerright_y : -0.153972
# resampling_kernel_type : SINC
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_91296\2687566843.py:75: RuntimeWarning: invalid value encountered in log
#   ( np.log( (c1 * (wavenum_ir[ch] * 100.)**3) / (gk2a_rad * 1.E-5) + 1.) )
# [Imaging Complete] : gk2a_ami_le1b_ir123_fd020ge_202103290300
# [Reading complete] GK-2A/AMI Channel Data
# All code complete
